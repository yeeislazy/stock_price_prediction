# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

df = pd.read_parquet(Path.cwd().parent / "data" / "qqq" / "training" / f"qqq_test.parquet")

# %%
df.plot(x="date", y="return_2", title="QQQ Closing Price Over Time")
df.plot(x="date", y="return_2", title="QQQ Closing Price Over Time")
# Out:
# <Axes: title={'center': 'QQQ Closing Price Over Time'}, xlabel='date'>
